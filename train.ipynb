# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 model
model = YOLO('../../best.pt')
'''
# Train the model
results = model.train(
    data='rock_paper_scissors/data.yaml'
    epochs=100,          # Number of training cycles
    imgsz=640,          # Image size
    batch=8,           # Batch size (reduce if you get memory errors)
    name='rps_model',   # Name for this training run
    patience=20         # Stop if no improvement for 20 epochs
)
'''

'''
# Retrain the model with enhanced data augmentation for rotation robustness
results = model.train(
    data='rock_paper_scissors/data.yaml'
    epochs=100,
    imgsz=640,
    batch=8,
    degrees=180,        # KEY: Allows any rotation
    flipud=0.5,         # KEY: Flips upside-down
    fliplr=0.5,
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    translate=0.1,
    scale=0.5,
    mosaic=1.0,
    name='rps_model_rotation_robust',
    patience=40,
    
    # Checkpoints
    save=True,             # Save checkpoints
    save_period=10,        # Save checkpoint every 10 epochs

    # Performance optimizations
    cache='ram',           # Cache images in RAM for faster training

    # Other useful parameters
    verbose=True,          # Show detailed training info
    val=True              # Run validation during training

)

'''

#results = model.val()  # evaluate model performance on the validation set
results = model('../../AISE_3350_Final_Course_Project_Group_18/rps-1_test2.jpg', save=True, show=True)  # predict on an image
#results = model.export(format='onnx')

# Testing relative path performance
#from pathlib import Path
#print(Path("../../AISE_3350_Final_Course_Project_Group_18/runs/detect/rps_model_rotation_robust2/weights/best.pt").resolve())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from ultralytics import YOLO
#       3 # Load a pretrained YOLOv11 model
# ----> 4 model = YOLO('../../best.pt')
#       5 '''
#       6 # Train the model
#       7 results = model.train(
#    (...)
#      14 )
#      15 '''
#      17 '''
#      18 # Retrain the model with enhanced data augmentation for rotation robustness
#      19 results = model.train(
#    (...)
#      48
#      49 '''
#
# File c:\Users\chibu\anaconda3\Lib\site-packages\ultralytics\models\yolo\model.py:76, in YOLO.__init__(self, model, task, verbose)
#      73     self.__dict__ = new_instance.__dict__
#      74 else:
#      75     # Continue with default YOLO initialization
# ---> 76     super().__init__(model=model, task=task, verbose=verbose)
# ...
